# %%
import obspy

# %%
from obspy import read, UTCDateTime
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
#%matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from obspy import Stream

# %%
r3 = read("UC_MNGR_2018071521.mseed");
cm3 = read("AM.R9C82.2018071521.mseed");
cu3 = read("UC.MNG2.EHZ-2018071521.mseed");

# %%
a3 = r3[0];
b3 = cm3[0];
c3 = cu3[0];

# %%
r4 = read("UC_MNGR_2018072513.mseed");
cg4 = read("AM.R9C82.2018072513.mseed");
cu4 = read("UC.MNG2.EHZ-2018072513.mseed");

# %%
a4 = r4[0];
b4 = cg4[0];
c4 = cu4[0];

a4.detrend();
b4.detrend();
c4.detrend();

# %%
r5 = read("UC_MNGR_2018072822.mseed");
c5 = read("AM.R9C82.2018072822.mseed");
cu5 = read("UC.MNG2.EHZ-2018072822.mseed");

# %%
a5 = r5[0];
b5 = c5[0];
c5 = cu5[0];

a5.detrend();
b5.detrend();
c5.detrend();

# %%
r6 = read("UC_MNGR_2018073013.mseed");
c6 = read("AM.R9C82.2018073013.mseed");
cu6 = read("UC.MNG2.EHZ-2018073013.mseed");

# %%
a6 = r6[0];
b6 = c6[0];
c6 = cu6[0];

a6.detrend();
b6.detrend();
c6.detrend();

# %%
r7 = read("UC_MNGR_2018081619.mseed");
c7 = read("AM.R9C82.2018081619.mseed");
cu7 = read("UC.MNG2.EHZ-2018081619.mseed");

# %%
a7 = r7[0];
b7 = c7[0];
c7 = cu7[0];

a7.detrend();
b7.detrend();
c7.detrend();

# %%
r8 = read("UC_MNGR_2018081722.mseed");
c8 = read("AM.R9C82.2018081722.mseed");
cu8 = read("UC.MNG2.EHZ-2018081722.mseed");

# %%
a8 = r8[0];
b8 = c8[0];
c8 = cu8[0];

a8.detrend();
b8.detrend();
c8.detrend();

# %%
r9 = read("UC_MNGR_2018081823_.mseed");
c9 = read("AM.R9C82.2018081823.mseed");
cu9 = read("UC.MNG2.EHZ-2018081823.mseed");

# %%
a9 = r9[0];
b9 = c9[0];
c9 = cu9[0];

a9.detrend();
b9.detrend();
c9.detrend();

# %%
r10 = read("UC_MNGR_2018082223_.mseed");
c10 = read("AM.R9C82.2018082223.mseed");
cu10 = read("UC.MNG2.EHZ-2018082223.mseed");

# %%
a10 = r10[0];
b10 = c10[0];
c10 = cu10[0];

a10.detrend();
b10.detrend();
c10.detrend();

# %%
r11 = read("UC_MNGR_2018082322.mseed");
c11 = read("AM.R9C82.2018082322.mseed");
cu11 = read("UC.MNG2.EHZ-2018082321.mseed");

# %%
a11 = r11[0];
b11 = c11[0];
c11 = cu11[0];

a11.detrend();
b11.detrend();
c11.detrend();

# %%
r17 = read("UC_MNGR_2018100623_.mseed");
c17 = read("AM.R9C82.2018100623.mseed");
cu17 = read("UC.MNG2.EHZ-2018100623.mseed");

# %%
a17 = r17[0];
b17 = c17[0];
c17 = cu17[0];

a17.detrend();
b17.detrend();
c17.detrend();

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("15/07/18 L3",fontsize=25)
plt.plot(a3,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b3,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c3,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([ -200000.,        0.,   200000.,   400000.,   600000.,   800000.,
#          1000000.,  1200000.,  1400000.,  1600000.]),
#  <a list of 10 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("25/07/18 L4",fontsize=25)
plt.plot(a4,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b4,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c4,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([ -500000.,        0.,   500000.,  1000000.,  1500000.,  2000000.,
#          2500000.,  3000000.,  3500000.]),
#  <a list of 9 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("28/07/18 L5",fontsize=25)
plt.plot(a5,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b5,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c5,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.]), <a list of 8 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("30/07/18 L6",fontsize=25)
plt.plot(a6,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b6,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c6,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([ -200000.,        0.,   200000.,   400000.,   600000.,   800000.,
#          1000000.]), <a list of 7 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("16/08/18 L7",fontsize=25)
plt.plot(a7,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b7,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c7,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([ -200000.,        0.,   200000.,   400000.,   600000.,   800000.,
#          1000000.,  1200000.]), <a list of 8 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("17/08/18 L8",fontsize=25)
plt.plot(a8,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b8,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c8,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.,  700000.,  800000.]),
#  <a list of 10 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("18/08/18 L9",fontsize=25)
plt.plot(a9,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b9,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c9,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.,  700000.,  800000.]),
#  <a list of 10 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("22/08/18 L10",fontsize=25)
plt.plot(a10,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b10,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c10,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.,  700000.,  800000.,  900000.]),
#  <a list of 11 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("22/08/18 L10",fontsize=25)
plt.plot(a11,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b11,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c11,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.,  700000.,  800000.]),
#  <a list of 10 Text xticklabel objects>)

# %%
plt.figure(figsize=(30,25))

plt.subplots_adjust(hspace=0)

plt.subplot(311)
plt.title("06/10/18 L17",fontsize=25)
plt.plot(a17,'r',label="RESCO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(312)
plt.plot(b17,'b',label="CGEO")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)

plt.subplot(313)
plt.plot(c17,'g',label="CUBE")
plt.yticks(fontsize=15)
legend(loc="best",fontsize=20)
plt.xticks(fontsize=20)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.,  600000.,  700000.,  800000.]),
#  <a list of 10 Text xticklabel objects>)

# %%
#stream.plot(equal_scale=False)
