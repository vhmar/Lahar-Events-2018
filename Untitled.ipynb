# %%
using SAC, DSP, PyPlot

# %%
l1 = SAC.read("UC.MNGR.20180715-Trim01.sac")
# Out:
# SAC.SACtr:
#     delta: 0.01
#    depmin: -30978.0
#    depmax: 31279.0
#     scale: 1.0
#         b: 0.0
#         e: 10799.99
#    depmen: -258.49796
#    nzyear: 2018
#    nzjday: 196
#    nzhour: 21
#     nzmin: 0
#     nzsec: 0
#    nzmsec: 0
#     nvhdr: 6
#      npts: 1080000
#    iftype: 1
#    iztype: 9
#     leven: true
#    lpspol: true
#    lovrok: true
#    lcalda: false
#  unused18: true
#     kstnm: MNGR
#    kcmpnm: HHN
#    knetwk: UC
# Info: Data are little-endian; byteswapping

# %%
fig = figure(figsize=(12,5))
plot(l1.t)
# Out:
# PyPlot.Figure(PyObject <Figure size 1200x500 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f7a2ff11c88>
